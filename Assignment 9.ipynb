# %% [raw]
# Ques 1.) To what does a relative path refer ?
#
# Solution :
#
# A relative path refers to the location of a file or directory relative to the current working directory or the location of the
# file or directory being referenced. It specifies the path starting from the current directory, rather than starting from the
# root directory.
#
# For example, let's say we have the following directory structure :
#
# - root
#     - folder1
#         - file1.txt
#     - folder2
#         - file2.txt
#     - file3.txt
#
# If our current working directory is root, then the relative path to file1.txt would simply be folder1/file1.txt. Similarly,
# the relative path to file2.txt would be folder2/file2.txt, and the relative path to file3.txt would be file3.txt.
#
# Relative paths are often used when referring to files or directories within the same project or directory structure. They
# provide a concise way to navigate and reference files without specifying the entire path from the root directory.

# %% [raw]
# Ques 2.) What does an absolute path start with your operating system ?
#
# Solution :
#
# In most operating systems, including Windows, macOS, and Linux, an absolute path starts with the root directory. The root
# directory is the highest-level directory in a file system hierarchy and is typically represented by a forward slash (/) in
# Unix-like systems (e.g., Linux and macOS) and by a drive letter followed by a colon (e.g., C:) in Windows.
#
# Here are some examples of absolute paths on different operating systems :
#
# * Unix-like systems (e.g., Linux, macOS) :
#
#   /home/user/Documents/file.txt (Absolute path to a file in the user's Documents directory)
#   /var/www/html/index.html (Absolute path to a file in the web server's document root directory)
#
# * Windows :
#
#   C:\Users\User\Documents\file.txt (Absolute path to a file in the user's Documents directory)
#   D:\Projects\project\index.html (Absolute path to a file on the D drive in a project directory)
#
# In these examples, the absolute paths provide the complete location of a file or directory in the file system, starting from
# the root directory.

# %% [raw]
# Ques 3.) What do the functions os.getcwd() and os.chdir() do ?
#
# Solution :
#
# The functions os.getcwd() and os.chdir() are part of the os module in Python and are used for working with file paths and
# directories.
#
# 1.) os.getcwd() :
#
#     * os.getcwd() returns a string representing the current working directory (CWD) of the Python script or the current
#       interactiveinterpreter session.
#
#     * The current working directory is the directory from which the Python script is executed or the directory where the
#       interpreter session is initiated.
#
# It can be useful for obtaining the current directory path to perform file operations or navigate relative paths based on the
# current working directory.
#
# Here's an example of how to use os.getcwd() :
#
# import os
#
# current_dir = os.getcwd()
# print("Current working directory:", current_dir)
#
# 2.) os.chdir(path) :
#
#     * os.chdir(path) changes the current working directory to the specified path.
#
#     * It takes a string argument path representing the directory path to which we want to change the working directory.
#
#     * This function is useful when we want to switch to a different directory to perform file operations or access files in
#       a specific directory.
#
# Here's an example of how to use os.chdir() :
#
# import os
#
# new_dir = "/path/to/new/directory"
# os.chdir(new_dir)
#
# After executing this code, the current working directory would be changed to '/path/to/new/directory'.
#
# By using os.getcwd() and os.chdir() together, we can obtain the current working directory and change it as needed to navigate
# and perform file operations in different directories within your Python script.

# %% [raw]
# Ques 4.) What are the . and .. folders ?
#
# Solution :
#
# In most operating systems, the . (dot) and .. (dot-dot) folders are special directory references that provide a way to navigate
# and reference directories within the file system.
#
# 1.) '.' (dot) :
#
#     * The '.' folder represents the current directory.
#     * It is used to refer to the directory itself when specifying file paths or executing commands.
#     * For example, if the current directory is /home/user, ./file.txt would refer to the file file.txt in the current directory.
#
# 2.) '..' (dot-dot) :
#
#     * The '..' folder represents the parent directory (one level up) relative to the current directory.
#     * It is used to navigate to the parent directory when specifying file paths or executing commands.
#     * For example, if the current directory is /home/user/folder, ../file.txt would refer to the file file.txt in the parent
#       directory (/home/user).
#
# These special directory references are commonly used in command-line interfaces and when working with file paths to provide
# relative references. They allow for navigation within the file system hierarchy without specifying the entire absolute path.

# %% [raw]
# Ques 5.) In C:\bacon\eggs\spam.txt, which part is the dir name, and which part is the base name ?
#
# Solution :
#
# In the file path C:\bacon\eggs\spam.txt, the directory name and the base name can be identified as follows :
#
# * Directory name : C:\bacon\eggs
#
# The directory name represents the path to the folder or directory where the file is located. In this case, the directory name
# is C:\bacon\eggs.
#
# * Base name : spam.txt
#
# The base name refers to the actual name of the file itself, without the directory path. In this case, the base name is spam.txt.
#
# To further clarify, the directory name provides the path to the folder or directory containing the file, while the base name
# represents the actual name of the file itself, including the file extension (in this case, .txt).
#
# It's worth noting that the directory name and base name are common terms used when working with file paths and can be relevant
# in various programming languages and operating systems.

# %% [raw]
# Ques 6.) What are the three “mode” arguments that can be passed to the open() function ?
#
# Solution :
#
# The open() function in Python accepts several mode arguments that determine how a file should be opened and accessed. The three
# main mode arguments are :
#
# 1.) Read Mode (mode='r') :
#
#     * This is the default mode if no mode argument is specified.
#     * It allows us to open a file for reading its contents.
#     * If the file doesn't exist or cannot be opened, it will raise a FileNotFoundError.
#     * Example : open("file.txt", mode="r")
#
# 2.) Write Mode (mode='w') :
#
#     * This mode allows us to open a file for writing.
#     * If the file exists, it will be truncated (emptied) before writing.
#     * If the file doesn't exist, a new file will be created.
#     * Example: open("file.txt", mode="w")
#
# 3.) Append Mode (mode='a') :
#
#     * This mode allows us to open a file for appending data.
#     * If the file exists, data will be added at the end of the file.
#     * If the file doesn't exist, a new file will be created.
#     * Example : open("file.txt", mode="a")
#
# These are the three most common mode arguments used with the open() function. Additionally, there are other mode arguments like
# binary mode ('b'), exclusive creation ('x'), and more, which can be combined with the main modes (e.g., 'rb' for read mode in
# binary). The mode argument specifies the intended use of the file and influences the file pointer's position, permissions, and
# how the file is handled during operations like reading and writing.

# %% [raw]
# Ques 7.) What happens if an existing file is opened in write mode ?
#
# Solution :
#
# When an existing file is opened in write mode (mode='w'), the following consequences occur :
#
# 1.) Truncation : The file is truncated, which means all existing content in the file is deleted and the file size becomes 0. If
#     there was any data in the file before opening it in write mode, that data will be completely erased.
#
# 2.) File Pointer : The file pointer is positioned at the beginning of the file, ready to write new content. Any write operations
#     performed will overwrite the existing data or append new data at the beginning of the file, depending on the specific write
#     operation used.
#
# 3.) File Creation : If the file specified does not exist, a new file will be created with the given name. This is true even
#     when opening the file in write mode (mode='w') without the file already existing.
#
# It's important to exercise caution when opening a file in write mode, as it can lead to irreversible data loss if existing
# content is overwritten. It is recommended to make sure we have a backup of the file or to use append mode (mode='a') instead
# if we want to preserve the existing data and append new content to the file.

# %% [raw]
# Ques 8.) How do you tell the difference between read() and readlines() ?
#
# Solution :
#
# In Python, the read() and readlines() methods are used to read data from a file, but they differ in how they handle and return
# the data:
#
# 1.) read() method :
#
#     * The read() method reads the entire contents of a file as a single string.
#     * It reads from the current file position or from the beginning if no file position has been set.
#     * The returned string includes all the characters in the file, including newlines and other whitespace characters.
#     * If the file is very large, reading the entire contents into memory as a single string may not be efficient.
#
# Example :
#
#     with open("file.txt", mode="r") as file:
#     contents = file.read()
#
# 2.) readlines() method :
#
#     * The readlines() method reads the contents of a file and returns a list of strings, where each string represents a line in
#       the file.
#     * It reads from the current file position or from the beginning if no file position has been set.
#     * The returned list contains each line as a separate string element, including the newline character at the end of each
#       line.
#     * This method is useful when we want to process the contents of a file line by line.
#
# Example :
#
#     with open("file.txt", mode="r") as file:
#     lines = file.readlines()
#
# To summarize, read() returns the entire contents of the file as a single string, while readlines() returns the contents of the
# file as a list of strings, where each string represents a line in the file. The choice between these methods depends on how we
# intend to process and work with the data from the file.

# %% [raw]
# Ques 9.) What data structure does a shelf value resemble ?
#
# Solution :
#
# In Python, the shelf module provides a dictionary-like interface for storing and retrieving Python objects on disk. It uses a
# disk-based format and implements key-value storage similar to a dictionary.
#
# The shelf data structure resembles a dictionary because it allows us to store and retrieve values using keys. It supports the
# usual dictionary operations like __getitem__ (using square brackets), __setitem__ (using assignment), __delitem__ (deletion),
# and iterating over keys and values.
#
# However, unlike an in-memory dictionary, a shelf object persists its data on disk, typically as a file. It uses Python's
# pickle module to serialize objects and store them in the file, allowing us to store and retrieve complex Python objects.
#
# Here's an example of using a shelf :
#
# import shelve
#
# # Creating a shelf and storing values
# with shelve.open("mydata") as s:
#     s["key1"] = "value1"
#     s["key2"] = [1, 2, 3]
#     s["key3"] = {"name": "John", "age": 25}
#
# # Retrieving values from the shelf
# with shelve.open("mydata") as s:
#     print(s["key1"])  # Output: value1
#     print(s["key2"])  # Output: [1, 2, 3]
#     print(s["key3"])  # Output: {"name": "John", "age": 25}
#
# In this example, the shelf behaves like a dictionary, allowing us to store and retrieve values using keys. However, the actual
# data is stored in a file (mydata), and the objects are serialized using pickle before being stored.
#
# Overall, a shelf data structure combines the features of a dictionary and persistence on disk, making it a convenient choice
# for storing and retrieving objects across multiple program runs or sharing data between different programs.
